# %% [markdown]
# ## Clasificación de plantas Iris

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
iris = pd.read_csv('iris.csv')

# %%
iris = iris.drop('Id', axis=1)

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# ### Visualizaciones:

# %%
iris.boxplot(by='Species', figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
sns.violinplot(data=iris, x='Species', y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.pairplot(iris, hue='Species')

# %% [markdown]
# ### Sépalo - Longitud vs. Ancho:

# %%
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='blue', label='Setosa')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='green', label='Versicolor', ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='red', label='Virginica', ax=fig)

fig.set_xlabel('Sépalo - Longitud')
fig.set_ylabel('Sépalo - Ancho')
fig.set_title('Sépalo - Longitud vs Ancho')
plt.show()

# %%
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='blue', label='Setosa')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='green', label='Versicolor', ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='red', label='Virginica', ax=fig)

fig.set_xlabel('Sépalo - Longitud')
fig.set_ylabel('Sépalo - Ancho')
fig.set_title('Sépalo - Longitud vs Ancho')
plt.show()

# %% [markdown]
# ### Aplicación de algoritmos de Machine learning:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

X = np.array(iris.drop(['Species'], 1))
y = np.array(iris['Species'])
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_6260/3027044932.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = np.array(iris.drop(['Species'], 1))

# %% [markdown]
# #### Modelo de regresión logística - Logistic regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)

print('Precisión de regresión logistica: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión de regresión logistica: 0.9666666666666667

# %%
#Resúmen de la predicción hecha con regresión logística:
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.82      1.00      0.90         9
#  Iris-virginica       1.00      0.85      0.92        13
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.95      0.94        30
#    weighted avg       0.95      0.93      0.93        30
#
# [[ 8  0  0]
#  [ 0  9  0]
#  [ 0  2 11]]

# %% [markdown]
# #### Modelo de máquinas de vectores de soporte - Support vector machine

# %%
algoritmo = SVC()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)

print('Precisión de máquinas de vectores de soporte: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión de máquinas de vectores de soporte: 0.9666666666666667

# %%
#Resúmen de la predicción hecha con support vector machine:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.75      1.00      0.86         9
#  Iris-virginica       1.00      0.77      0.87        13
#
#        accuracy                           0.90        30
#       macro avg       0.92      0.92      0.91        30
#    weighted avg       0.93      0.90      0.90        30
#
# [[ 8  0  0]
#  [ 0  9  0]
#  [ 0  3 10]]

# %% [markdown]
# #### Modelo de vecinos más cercanos - K-Nearest Neighbors

# %%
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)

print('Precisión de vecinos más cercanos: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión de vecinos más cercanos: 0.9666666666666667

# %%
#Resúmen de la predicción hecha con K-nearest neighbors:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.75      1.00      0.86         9
#  Iris-virginica       1.00      0.77      0.87        13
#
#        accuracy                           0.90        30
#       macro avg       0.92      0.92      0.91        30
#    weighted avg       0.93      0.90      0.90        30
#
# [[ 8  0  0]
#  [ 0  9  0]
#  [ 0  3 10]]

# %% [markdown]
# #### Modelo de arboles de decisión clasificación - Decision tree classifier

# %%
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)

print('Precisión Árboles de Decisión Clasificación: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Árboles de Decisión Clasificación: 1.0

# %%
#Resúmen de la predicción hecha con Decision tree classifier:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.90      1.00      0.95         9
#  Iris-virginica       1.00      0.92      0.96        13
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30
#
# [[ 8  0  0]
#  [ 0  9  0]
#  [ 0  1 12]]

# %% [markdown]
# ##### Acá el resultado es igual a 1, es decir que este modelo es perfecto, por lo que sería el ideal para realizar las próximas predicciones.

# %% [markdown]
# ### Nuevo modelo (solo evalúa los datos del sépalo):

# %%
sepalo = iris[['SepalLengthCm','SepalWidthCm','Species']]

X_sepalo = np.array(sepalo.drop(['Species'], 1))
y_sepalo = np.array(sepalo['Species'])

X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_sepalo, y_sepalo, test_size=0.2)
print('Son {} datos del sépalo para entrenamiento y {} datos sépalo para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 120 datos del sépalo para entrenamiento y 30 datos sépalo para prueba
# C:\Users\PC\AppData\Local\Temp/ipykernel_6260/3356151202.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_sepalo = np.array(sepalo.drop(['Species'], 1))

# %% [markdown]
# #### Modelo de regresión logística - Logistic regressionregresión logística:

# %%
algoritmo = LogisticRegression()
algoritmo.fit(X_train_s, y_train_s)
Y_pred = algoritmo.predict(X_test_s)

print('Precisión Regresión Logística - Sépalo: {}'.format(algoritmo.score(X_train_s, y_train_s)))
# Out:
# Precisión Regresión Logística - Sépalo: 0.8333333333333334

# %%
#Resúmen de la predicción hecha con Logistic regression:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.25      0.38      0.30         8
# Iris-versicolor       0.33      0.33      0.33         9
#  Iris-virginica       0.56      0.38      0.45        13
#
#        accuracy                           0.37        30
#       macro avg       0.38      0.36      0.36        30
#    weighted avg       0.41      0.37      0.38        30
#
# [[3 3 2]
#  [4 3 2]
#  [5 3 5]]

# %% [markdown]
# #### Modelo de máquinas de vectores de soporte - Support vector machine

# %%
algoritmo = SVC()
algoritmo.fit(X_train_s, y_train_s)
Y_pred = algoritmo.predict(X_test_s)

print('Precisión Máquinas de Vectores de Soporte - Sépalo: {}'.format(algoritmo.score(X_train_s, y_train_s)))
# Out:
# Precisión Máquinas de Vectores de Soporte - Sépalo: 0.8416666666666667

# %%
#Resúmen de la predicción hecha con support vector machine:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.25      0.38      0.30         8
# Iris-versicolor       0.33      0.33      0.33         9
#  Iris-virginica       0.56      0.38      0.45        13
#
#        accuracy                           0.37        30
#       macro avg       0.38      0.36      0.36        30
#    weighted avg       0.41      0.37      0.38        30
#
# [[3 3 2]
#  [4 3 2]
#  [5 3 5]]

# %% [markdown]
# #### Modelo de vecinos más cercanos - K-Nearest Neighbors

# %%
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train_s, y_train_s)
Y_pred = algoritmo.predict(X_test_s)

print('Precisión Vecinos más Cercanos - Sépalo: {}'.format(algoritmo.score(X_train_s, y_train_s)))
# Out:
# Precisión Vecinos más Cercanos - Sépalo: 0.8333333333333334

# %%
#Resúmen de la predicción hecha con K-nearest neighbors:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.25      0.38      0.30         8
# Iris-versicolor       0.38      0.33      0.35         9
#  Iris-virginica       0.60      0.46      0.52        13
#
#        accuracy                           0.40        30
#       macro avg       0.41      0.39      0.39        30
#    weighted avg       0.44      0.40      0.41        30
#
# [[3 3 2]
#  [4 3 2]
#  [5 2 6]]

# %% [markdown]
# #### Modelo de arboles de decisión clasificación - Decision tree classifier

# %%
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train_s, y_train_s)
Y_pred = algoritmo.predict(X_test_s)

print('Precisión Árboles de Decisión Clasificación - Sépalo: {}'.format(algoritmo.score(X_train_s, y_train_s)))
# Out:
# Precisión Árboles de Decisión Clasificación - Sépalo: 0.9333333333333333

# %% [markdown]
# ##### Este es el mejor de los resultados, por lo que este es el mejor modelo de todos.

# %%
#Resúmen de la predicción hecha con decision tree classifier:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.25      0.38      0.30         8
# Iris-versicolor       0.30      0.33      0.32         9
#  Iris-virginica       0.38      0.23      0.29        13
#
#        accuracy                           0.30        30
#       macro avg       0.31      0.31      0.30        30
#    weighted avg       0.32      0.30      0.30        30
#
# [[3 2 3]
#  [4 3 2]
#  [5 5 3]]

# %% [markdown]
# ### Nuevo modelo que evalúa los datos correspondientes al pétalo (longitud, ancho y la columna de especies, que sería la etiqueta):

# %%
petalo = iris[['PetalLengthCm','PetalWidthCm','Species']]

X_petalo = np.array(petalo.drop(['Species'], 1))
y_petalo = np.array(petalo['Species'])

X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(X_petalo, y_petalo, test_size=0.2)
print('Son {} datos de pétalo para entrenamiento y {} datos de pétalo para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 120 datos de pétalo para entrenamiento y 30 datos de pétalo para prueba
# C:\Users\PC\AppData\Local\Temp/ipykernel_6260/3963163918.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_petalo = np.array(petalo.drop(['Species'], 1))

# %% [markdown]
# #### Modelo de regresión logística - Logistic regression

# %%
algoritmo = LogisticRegression()
algoritmo.fit(X_train_p, y_train_p)
Y_pred = algoritmo.predict(X_test_p)

print('Precisión Regresión Logística - Pétalo: {}'.format(algoritmo.score(X_train_p, y_train_p)))
# Out:
# Precisión Regresión Logística - Pétalo: 0.975

# %%
#Resúmen de la predicción hecha con logistic regression:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.27      0.38      0.32         8
# Iris-versicolor       0.50      0.56      0.53         9
#  Iris-virginica       0.33      0.23      0.27        13
#
#        accuracy                           0.37        30
#       macro avg       0.37      0.39      0.37        30
#    weighted avg       0.37      0.37      0.36        30
#
# [[3 1 4]
#  [2 5 2]
#  [6 4 3]]

# %% [markdown]
# #### Modelo de máquinas de vectores de soporte - Support vector machine

# %%
algoritmo = SVC()
algoritmo.fit(X_train_p, y_train_p)
Y_pred = algoritmo.predict(X_test_p)

print('Precisión Máquinas de Vectores de Soporte - Pétalo: {}'.format(algoritmo.score(X_train_p, y_train_p)))
# Out:
# Precisión Máquinas de Vectores de Soporte - Pétalo: 0.9666666666666667

# %%
#Resúmen de la predicción hecha con support vector machine:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.27      0.38      0.32         8
# Iris-versicolor       0.56      0.56      0.56         9
#  Iris-virginica       0.30      0.23      0.26        13
#
#        accuracy                           0.37        30
#       macro avg       0.38      0.39      0.38        30
#    weighted avg       0.37      0.37      0.36        30
#
# [[3 0 5]
#  [2 5 2]
#  [6 4 3]]

# %% [markdown]
# #### Modelo de vecinos más cercanos - K-Nearest Neighbors

# %%
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train_p, y_train_p)
Y_pred = algoritmo.predict(X_test_p)

print('Precisión Vecinos más Cercanos - Pétalo: {}'.format(algoritmo.score(X_train_p, y_train_p)))
# Out:
# Precisión Vecinos más Cercanos - Pétalo: 0.9833333333333333

# %%
#Resúmen de la predicción hecha con K-Nearest Neighbors:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.27      0.38      0.32         8
# Iris-versicolor       0.50      0.56      0.53         9
#  Iris-virginica       0.33      0.23      0.27        13
#
#        accuracy                           0.37        30
#       macro avg       0.37      0.39      0.37        30
#    weighted avg       0.37      0.37      0.36        30
#
# [[3 1 4]
#  [2 5 2]
#  [6 4 3]]

# %% [markdown]
# #### Modelo de arboles de decisión clasificación - Decision tree classifier

# %%
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train_p, y_train_p)
Y_pred = algoritmo.predict(X_test_p)

print('Precisión Árboles de Decisión Clasificación - Pétalo: {}'.format(algoritmo.score(X_train_p, y_train_p)))
# Out:
# Precisión Árboles de Decisión Clasificación - Pétalo: 0.9916666666666667

# %%
#Resúmen de la predicción hecha con Decision tree classifier:

print(classification_report(y_test, Y_pred))
print(confusion_matrix(y_test, Y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.27      0.38      0.32         8
# Iris-versicolor       0.50      0.56      0.53         9
#  Iris-virginica       0.33      0.23      0.27        13
#
#        accuracy                           0.37        30
#       macro avg       0.37      0.39      0.37        30
#    weighted avg       0.37      0.37      0.36        30
#
# [[3 1 4]
#  [2 5 2]
#  [6 4 3]]

# %% [markdown]
# ##### La precisión de este algoritmo es el mejor resultado de todos los algoritmos que evaluamos con estos datos.

# %% [markdown]
# #### En conclusión, se construyeron varios modelos con tres conjuntos de datos, pero el modelo construido con el algoritmo de Árbol de Decisión Clasificación es el que obtuvo los mejores resultados en cuanto a la precisión.
